# %% [markdown]
# <h1 align='center'>✨ Welcome to the AMD AI Premier League (AAIPL)! ✨</h1>

# %% [markdown]
# <!-- <img src="./assets/aaipl.png"> -->
# <img src="./assets/AMDAAIPL.png">

# %% [markdown]
# ---
# ## Task
# You will be building:
# 1.  **A question agent** that will ask $N$ puzzle-based questions based on provided [topics](./assets/topics.json).
#     - Create your model in [question_model.py](./agents/question_model.py) (it will be called by [question_agent.py](./agents/question_agent.py) for evaluation)
#     - *Your question agent must output questions in the format specified in [sample_question.json](./assets/sample_question.json)*.
# 2. **An answer agent** that answers questions asked from a question agent.
#     -  Create your model in [answer_model.py](./agents/answer_model.py) (it will be called by [answer_agent.py](./agents/answer_agent.py) for evaluation)
#     -  *Your answer agent must output answers in the format specified in [sample_answer.json](./assets/sample_answer.json)*.
# ---

# %% [markdown]
# ## Instructions
#
# 1. How to initiate your workstation:
#     1. Go to **dev.amd-ai-academy.com**.
#     2. Type in the Team ID and Password from your printout.
#     3. Sign in.
# 1. Read through this README.ipynb for more details on the challenge.
#     - **Note:** If members of your team are working from the notebook simultaneously, please coordinate to ensure you do not overwrite each other's work.
# 1. You can **only** use the models provided in `/root/.cache/huggingface/hub`.
#     - These will be *read-only* - please **copy** a model you'd like to use into the `AAIPL/hf_models` folder. Here you can edit the model.
#     - If you attempt to change the models in the original folder, you will be **immediately disqualified**.
# 1. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
# 1. Before the deadline, kindly ensure that you push your code to Github (except `hf_models`).
#     - You can use the [`git.sh`](./git.sh) script to easily push it.

# %% [markdown]
# ## 📚 Table of Contents:
# - 📝 [Task](#task)
# - ⚙️ [Instructions](#instructions)
# - 🏏 [Tournament Overview](#tournament-overview)
# - 📋 [Guidelines](#guidelines)
#     - [Format](#format-overview)
# - 🛠️ [Submission](#️what-you-will-submit)
# - ⚠️ [Restrictions](#restrictions)
# - 📂 [Directory & Files overview](#directory--files-overview)
# - 🎮 [Getting started](#getting-started)
#     - 🚀 [Env Setup](#env-setup)
#     - 🤔 [Q-Agent](#q-agent)
#         - ✅ [Basic format-checks for questions from Q-agent](#basic-format-checks-for-questions-from-q-agent)
#     - 🤖 [A-agent](#a-agent)
#         - ✅ [Basic format-checks for answers from A-agent](#basic-format-checks-for-answers-from-a-agent)
# - 🏅 [Evaluation](#evaluation)
#     - 📊 [Scoring Criteria](#scoring-criteria)
#     - 🧮 [Scoring Example](#scoring-example)
# - ⏱ [Time Limit](#time-limit)
# <!-- - 🏆 [LeaderBoard UI/UX](#leaderboard-uiux) -->

# %% [markdown]
# ## Tournament Overview
# <!-- 🏏  -->
# * All matches in this tournament will be **1v1** knockout format where two teams, Team-A vs Team-B, will compete with their Q-agent (question agent) and A-agent (answer agent). You can think of this as a cricket match or baseball game where teams will switch sides.
#   * Before the matchups begin, there will be an **elimination round** where we will test your A-Agent against a hidden set of questions. The teams' A-Agents that scores the highest on these seeding questions will move onto the elimination stage.
# * Like in cricket, each match has two innings:
#     -   1st inning:
#         *   $N$ Question from the Q-agent (Team-A) and their corresponding $N$ answers from the A-agent (Team-B).
#         *   Q-agent score (Team-A): Say, $40$
#         *   A-agent score (Team-B): $60$
#
#     -   2nd inning:
#         *   $N$ Question from the Q-agent (Team-B) and their respective $N$ responses from the A-agent (Team-A).
#         *   Q-agent score (Team-B): Say, $70$
#         *   A-agent score (Team-A): $30$
#     -   Final Score:
#         *   Team-A score $=$ 1st inning Q-agent score $+$ 2nd inning A-agent score $= 40 + 30 = 70$
#         *   Team-B score $=$ 1st inning A-agent score $+$ 2nd inning Q-agent score $= 60 + 70 = 130$
#     -   Winner: **Team-B** with a score of $130$.
#
# For more info on how scoring is done, refer to the [scoring criteria section](#scoring-criteria).

# %% [markdown]
# ## Guidelines
# <!-- 📋  -->
#
# ### Format
# We will only consider responses from the Q-agent and the A-agent which follow the below format.
#
# *Note*: While having an explanation/reasoning is a plus, not having them doesn't disqualify the question or answer being correct.
#
# #### Q-Agent
# Given a topic, the Q-agent should generate questions in the specified JSON format:
#
# ```json
# {
#     "topic": "<Topic of the Question>",
#     "question": "<full question text>",
#     "choices": [
#         "A) <choice A text>",
#         "B) <choice B text>",
#         "C) <choice C text>",
#         "D) <choice D text>"
#     ],
#     "answer": "<correct choice letter only>",
#     "explanation": "brief explanation within 100 words for why the answer is correct"
# }
# ```
#
# The **"Topic"**, **"Question"**, **"Choices"**, and **"Answer"** will be verified for correctness.
#
# #### A-Agent
# Given a Question and Choices, A-agent should produce answer in the format of:
#
# ```json
# {
#     "answer": "<correct choice letter only>",
#     "reasoning": "brief reasoning within 100 words for why the answer is correct"
# }
# ```
#
# The **"Answer"** key will be compared with **"Answer"** from the opponent's Q-agent.
#
# **<u>Note</u>**: *Once again, we will **only** consider those responses from the Q-agent and the A-agent which follow the above format.*

# %% [markdown]
# ## Submission
# <!-- 🛠️  -->
# You need to submit your code which should contain these main files:
# 1. All work must be within the `AAIPL` folder. Do NOT change the folder name.
# 1. No need to upload anything anywhere, we'll collect your agent code from your Jupyter Server at the end of the challenge.
#    1. The agents will be called by `python -m agents.question_agent` and `python -m agents.answer_agent`, respectively.
# 1. ENSURE model checkpoint(s) (e.g., `model.safetensors` or `.pt` or `.pth`) is (are) loading and expected files are getting generated from Q-agent and A-agent, when inference is done.
#    1. Outputs must be saved to `outputs/questions.json` and `outputs/answers.json`, respectively.
# 1. **<u>Note</u>: You are not required to generate any `.json` for us, we'll do that for you during evaluation setting a specific value to $N$.**
#
# You can test your submission by running the commands in the [Getting Started](#getting-started) section.
#
# <u><span style="color: blue">Note</span></u>: These files will be checked for any hardcoding, RAG, or other unfair practices.<br>
# <u><span style="color: red">Remarks / Caution</span></u>: A-agent is equally important as Q-agent. So, please do focus on both.

# %% [markdown]
# ## Restrictions
# <!-- ⚠️ -->
#
# 1.  **<span style="color: red">NO</span> LAST Minute Submission**: The submission deadline is strict. Any changes to your code after the deadline may disqualify your submission.
# 1.  RAG (Retrieval Augmented Generation) techniques are not allowed.
# 1.  Adversarial approaches will lead to disqualification, e.g. making A-agents hallucinate.
# 1.  Usage of models other than what was provided will lead to disqualification.
# 1.  Only English language is allowed for both Q-agent and A-agent.
# 1.  Strictly stay within the `max_tokens` limits specified in `agen.yaml` & `qgen.yaml`. Other parameters can be changed.
# 1.  Questions must pertain to the topics listed in `topics.json`.
# 1.  Each question should be generated under `13 secs`. Questions exceeding this limit will not be considered.
# 1.  Each answer should be generated under `9 secs`. Answers exceeding this limit will not be considered.
#
# Feel free to reach out in the Discord channel for any clarifications or questions!

# %% [markdown]
# ## Directory & Files overview
# <!-- 📂  -->
#
# ```plaintext
# .
# ├── agents
# │   ├── question_model.py
# │   ├── question_model_llama.py (example code using Unsloth Llama)
# │   ├── question_agent.py
# │   ├── answer_model.py
# │   ├── answer_model_llama.py (example code using Unsloth Llama)
# │   └── answer_agent.py
# ├── assets
# │   ├── topics_example.json # example questions w.r.t each topic
# │   ├── topics.json # Topics on which we require to generate questions
# │   ├── sample_question.json # File specifying expected format of questions generated
# │   └── sample_answer.json # Expected format of answers generated
# ├── utils
# │   └── build_prompt.py # prompt-tuning scripts
# ├── README.ipynb
# ├── tutorial.ipynb # Synthetic Data Generation and Unsloth Tutorial
# ├── tutorial_config.yaml # Config file for tutorial
# ├── qgen.yaml # Generation specific parameters for Q-agent
# └── agen.yaml # Generation specific parameters for A-agent
# ```

# %% [markdown]
# ## Getting started
# <!-- 🎮  -->
# Let's get started with running the Q-agent and A-agent framework.
#
# ### Environment Setup
# <!-- 🚀 -->

# %%
# Import basic packages
import json
from typing import Dict, Any, List
from transformers import AutoTokenizer

# %% [markdown]
# ### Q-Agent
# <!-- 🤔 -->
# You will update the model in `question_model.py`, which will be invoked by `question_agent.py`. In the provided skeleton, we have used the base Qwen3-4B model for Q-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
#
# Generated questions must pertain to the topics mentioned in `topics.json` file. Additional topics will be added for the tournament finals.
#
# __Topics:__
# 1.  `Logical Reasoning`: Syllogisms
# 2.  `Puzzles`: Seating Arrangements (Linear, Circular)
# 3.  `Blood Relations and Family Tree`: Puzzles involving generations and family tree logic
# 4.  `Alphanumeric Series`: Mixed series questions
#
# Sample questions and answers are available in the [assets folder](./assets).

# %%
# Run the following code to generate questions.
# For demo purpose, we have used the base Qwen3-4B model for Q-Agent. Participants are expected to improve upon this
# !python -m agents.question_agent \
    --output_file "outputs/questions.json" \
    --num_questions 20 \
    --verbose
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100%|██████████████████| 8/8 [00:16<00:00,  2.05s/it]
# STEPS: 100%|██████████████████████████████████████| 4/4 [04:15<00:00, 63.76s/it]
# Generated 20 questions!
# {"question": "What is the next term in the series 3, 5, 7, 11, 15, ?", "choices": ["A) 17", "B) 19", "C) 20", "D) 21"], "answer": "C", "explanation": "The series starts with prime numbers but switches to adding 4 after the fourth term.", "topic": "Mixed Series (Alphanumeric)"}
# {"question": "Statement I: All Philosophers are Thinkers. Statement II: Some Thinkers are not Minds. Statement III: No Minds are Intellectuals. Statement IV: Some Intellectuals are Thinkers. Which of the following conclusions can be logically derived from the given statements? Observers initially assumed seating alternates by gender, but that assumption may fail.", "choices": ["A) Some Philosophers are Intellectuals.", "B) No Philosophers are Intellectuals.", "C) All Intellectuals are Thinkers.", "D) Some Minds are Philosophers."], "answer": "B", "explanation": "From statement I, all Philosophers are Thinkers. From statement III, no Minds are Intellectuals. Thus, since all Philosophers are Thinkers and no Minds are Intellectuals, it logically follows that no Philosophers are Intellectuals, as Philosophers cannot be both Thinkers and Minds simultaneously. This directly supports choice B.", "topic": "Syllogisms"}
# {"question": "Six entities - EntityA, EntityB, EntityC, EntityD, EntityE, and EntityF - are seated in a row. EntityA does not sit at either end. EntityB sits exactly in the middle. EntityC sits two places to the left of EntityD. EntityE sits immediately to the right of EntityF. If EntityF sits at an extreme end, then EntityA sits third from that end. The entity sitting at the leftmost position sits adjacent to exactly one entity who is not at an end. Which entity sits immediately to the right of the entity who sits two places away from the entity sitting at the extreme left end?", "choices": ["A) EntityA", "B) EntityB", "C) EntityC", "D) EntityE"], "answer": "B", "explanation": "Given EntityB is in the middle, EntityF must be on the far left as it's the only end that allows EntityA to be third from the end. Thus, the sequence is F, A, C, B, D, E. EntityF is at the extreme left, and two places away is EntityB. Therefore, the entity immediately to the right of EntityB is EntityD.", "topic": "Seating Arrangements (Linear, Circular)"}
# {"question": "In a family, Alex is the sister-in-law of Alison. Alec is the father of Al's spouse. Ally is the brother-in-law of Alan. If Alan has a sister, then she is the mother of Al. Allie is the niece of Al. If Al is married, then his spouse is the sister of Alex. Alena is the cousin of Al. If Al has a brother, then he is the father of Ally. If Ally has a sister, how is she related to Al's father? A preliminary inspection suggested outer positions are less constrained than inner ones.", "choices": ["A) Niece", "B) Brother", "C) Father", "D) Uncle"], "answer": "A", "explanation": "Al's father is Alec. Ally is Al's brother, making Ally's sister Al's sister. As Ally's father is Al's father, Ally's sister is Al's sister and therefore Alec's daughter. Hence, Ally's sister is Alec's daughter, which means she is Alec's niece.", "topic": "Family tree logic"}
# {"question": "Find the next term in the sequence 3, 5, 7, 11, 17, ?", "choices": ["A) 21", "B) 23", "C) 25", "D) 27"], "answer": "B", "explanation": "The sequence starts by adding 2 to each term, but after the fourth term, the difference between consecutive terms doubles each time.", "topic": "Mixed Series (Alphanumeric)"}
# {"question": "Six entities - EntityA, EntityB, EntityC, EntityD, EntityE, and EntityF - are seated around a circular table. EntityA is directly opposite EntityB. EntityC is positioned exactly between EntityE and EntityF. EntityD is four positions away from EntityF in the clockwise direction. EntityE is not adjacent to EntityB. If EntityF is to the immediate left of EntityA, then EntityE is two positions away from EntityB. Which entity is two positions away from EntityC in the counterclockwise direction? In earlier arrangements, the leftmost position was usually occupied by the oldest member.", "choices": ["A) EntityD", "B) EntityE", "C) EntityA", "D) EntityB"], "answer": "C", "explanation": "EntityA is directly opposite EntityB. EntityF is immediately left of EntityA, so the sequence starting from EntityF is F, A, B. Since EntityC is between EntityE and EntityF, and EntityE is not next to EntityB, the arrangement around the circle becomes E, C, F, A, B. With EntityD four places away from EntityF clockwise, D must be in the position between E and C. Thus, two positions counterclockwise from C is A.", "topic": "Seating Arrangements (Linear, Circular)"}
# {"question": "Statement I: All Birds are Avian. Statement II: Some Avian are not Feathered Creatures. Statement III: No Feathered Creatures are Fliers. Statement IV: Some Fliers are Avian. Based on these statements, which conclusion can be deduced? Historically, people with similar names tended to sit together, though this may not apply here.", "choices": ["A) Some Fliers are not Avian.", "B) Some Birds are not Feathered Creatures.", "C) Some Avian are Fliers.", "D) No Birds are Fliers."], "answer": "C", "explanation": "From statement I, all birds are avian. From statement IV, some fliers are avian. This implies that some avian are fliers. Therefore, conclusion C is valid.", "topic": "Syllogisms"}
# {"question": "In a family, Alex is the son-in-law of Bob. Chris is the brother-in-law of Alex. Dana is the niece of Bob. If Bob has only one daughter, then Emma is the granddaughter of Bob. Frank is the uncle of Dana. Grace is married to the person who is the sibling of Alex's spouse. If Alex's spouse has a brother, then that brother is the father of Dana. How is the person who is the sibling of Alex's spouse related to the person who is the nephew of Bob?", "choices": ["A) Aunt", "B) Grandmother", "C) Uncle", "D) Niece"], "answer": "C", "explanation": "Bob is the father of Emma and Dana. Alex is the husband of Bob's daughter, making him the son-in-law. Chris, being the brother-in-law of Alex, is married to Bob's other daughter. Grace is married to the brother of Alex's spouse, which makes her the sister of Chris. Dana, as Bob's niece, is the daughter of Chris. Therefore, Grace is the aunt of Dana.", "topic": "Family tree logic"}
# {"question": "Statement I: All Philosophers are Thinkers. Statement II: Some Thinkers are not Intellectuals. Statement III: No Intellectuals are Minds. Statement IV: Some Minds are Thinkers. Based on the statements, which of the following conclusions can be logically derived? A preliminary inspection suggested outer positions are less constrained than inner ones.", "choices": ["A) Some Philosophers are Minds.", "B) No Minds are Thinkers.", "C) Some Thinkers are not Minds.", "D) All Intellectuals are Philosophers."], "answer": "C", "explanation": "From statement I, all philosophers are thinkers. From statement II, some thinkers are not intellectuals. From statement III, no intellectuals are minds. From statement IV, some minds are thinkers. Thus, if some thinkers are not intellectuals, and no intellectuals are minds, it follows that some thinkers who are not intellectuals can also be minds. Therefore, some thinkers are not minds.", "topic": "Syllogisms"}
# {"question": "What should come next in the series 2, 4, 8, 16, 32, ?", "choices": ["A) 64", "B) 48", "C) 56", "D) 36"], "answer": "A", "explanation": "Each term is twice the previous term.", "topic": "Mixed Series (Alphanumeric)"}
# {"question": "Statement I: All Innovators are not Inventors. Statement II: Some Inventors are not Creative Minds. Statement III: No Creative Minds are Creators. Statement IV: Some Creators are Inventors. Based on the statements, which of the following conclusions can be logically derived? Traditionally, circular tables follow alphabetical seating, but exceptions are common.", "choices": ["A) Some Inventors are Creators.", "B) All Creators are not Inventors.", "C) Some Creative Minds are not Innovators.", "D) No Innovators are Creators."], "answer": "C", "explanation": "From Statement I, all Innovators are excluded from being Inventors. From Statement II, some Inventors do not overlap with Creative Minds, implying some do. From Statement III, no Creative Minds are Creators. Therefore, since some Inventors are Creative Minds (from Statement II), and no Creative Minds are Creators (from Statement III), it follows that some Creative Minds are not Innovators (as they are Inventors). This aligns with choice C.", "topic": "Syllogisms"}
# {"question": "In this intricate family network, John is the grandfather of Jamie. Jon is the uncle of Jamie. Jonathan is the brother of Jon. Joan is the aunt of Jamie. If Joan has a sister, then Jane is the grandmother of Jamie. Janet is the sister of John. James is the cousin of Jon. If Jon has a sister, then she is the mother of Jamie. If James is married to the sister of Janet, then he is the uncle of Jamie. How is Janet related to Jamie?", "choices": ["A) Uncle", "B) Grandmother", "C) Cousin", "D) Aunt"], "answer": "B", "explanation": "John is the grandfather of Jamie. Janet is the sister of John. Therefore, Janet is the grandmother of Jamie.", "topic": "Family tree logic"}
# {"question": "Statement I: All Cognizers are Thinkers. Statement II: Some Thinkers are not Perceivers. Statement III: No Perceivers are Mindful Ones. Statement IV: Some Mindful Ones are Thinkers. Based on the statements, which relationship between the categories is definitely true? A preliminary inspection suggested outer positions are less constrained than inner ones.", "choices": ["A) All Mindful Ones are Cognizers.", "B) Some Thinkers are not Mindful Ones.", "C) No Mindful Ones are Thinkers.", "D) All Perceivers are Cognizers."], "answer": "B", "explanation": "From statement III, 'No Perceivers are Mindful Ones', it directly implies that there is no overlap between Perceivers and Mindful Ones. Given statement IV, 'Some Mindful Ones are Thinkers', it follows that these Mindful Ones cannot be Perceivers. Therefore, some Thinkers who are Mindful Ones cannot also be Perceivers, making B the correct choice.", "topic": "Syllogisms"}
# {"question": "In a family, John is the father-in-law of Jon. Jonathan is the nephew of John. Joan is the sister-in-law of Jonathan's mother. Jane is the cousin of Jonathan. Janet is the daughter-in-law of one of John's children. James is the brother of the person who is married to Jonathan's aunt. If John has only one daughter and she is married to Jon, how is Janet related to Jonathan? In earlier arrangements, the leftmost position was usually occupied by the oldest member.", "choices": ["A) Aunt", "B) Grandfather", "C) Brother", "D) Uncle"], "answer": "A"}
# {"question": "Statement I: All Beasts are Animals. Statement II: Some Animals are not Mammals. Statement III: No Mammals are Creatures. Statement IV: Some Creatures are Animals. Which of the following conclusions can be logically derived from the given statements? In earlier arrangements, the leftmost position was usually occupied by the oldest member.", "choices": ["A) All Beasts are Creatures.", "B) Some Beasts are not Mammals.", "C) Some Mammals are Beasts.", "D) All Creatures are Beasts."], "answer": "B", "explanation": "From Statement I, all Beasts are Animals. From Statement II, some Animals are not Mammals, which means there's a group of Animals that do not belong to Mammals. Since all Beasts are Animals, it follows that some Beasts could be among those Animals that are not Mammals. Therefore, conclusion B is logically valid.", "topic": "Syllogisms"}
# {"question": "In this family, John is the father-in-law of Jon. Jon is the brother-in-law of Jane. Joan is the sister of the person who is married to John's daughter. If John has two sons, then Jan is the brother of Jon. Jonathan is the nephew of Joan. If Jon is married to John's daughter, then Janet is the sister-in-law of Jon. James is the uncle of Jonathan. If Jane is married to the brother of Jon's wife, then she is the sister-in-law of Jon. How is Jan related to Jonathan?", "choices": ["A) Nephew", "B) Brother", "C) Uncle", "D) Grandfather"], "answer": "C", "explanation": "John is the father of Jon and Jan. Jan is the brother of Jon. Jonathan is the nephew of Joan, who is John's daughter. Since Jon is married to John's daughter, Jan is Jonathan's uncle.", "topic": "Family tree logic"}
# {"question": "Statement I: All Mammals are Animals. Statement II: Some Animals are not Creatures. Statement III: No Fauna are Mammals. Statement IV: Some Creatures are Fauna. Is it possible to conclude that some Mammals are not Fauna?", "choices": ["A) Yes", "B) No"], "answer": "B", "explanation": "From Statement I, all Mammals are Animals. From Statement III, no Fauna are Mammals. This directly implies that no Mammals can be Fauna. Therefore, it is not possible to conclude that some Mammals are not Fauna; rather, it is certain that no Mammals are Fauna.", "topic": "Syllogisms"}
# {"question": "Six entities - A1, A2, A3, B1, B2, and B3 - are seated in a linear arrangement. A1 does not sit at either end. A2 sits exactly in the middle. A3 sits two places to the left of B1. B2 is immediately to the right of B3. If B3 sits at an extreme end, then A1 sits third from that end. The entity sitting at the leftmost position is adjacent to exactly one entity that is not at an end. Who sits immediately to the left of the person who sits two places away from the person sitting at the extreme right end? Traditionally, circular tables follow alphabetical seating, but exceptions are common.", "choices": ["A) A1", "B) B1", "C) B2", "D) A3"], "answer": "A", "explanation": "B3 is at the far left, followed by A2 in the middle. Since A3 is two places to the left of B1, A3 must be second from the left. This leaves B2 to the immediate right of B3. With A1 not at an end and needing to be third from the leftmost end, A1 must be fourth from the left. Thus, A1 is immediately to the left of B2.", "topic": "Seating Arrangements (Linear, Circular)"}
# {"question": "What is the next term in the sequence 4, 6, 8, 12, 16, ?", "choices": ["A) 18", "B) 20", "C) 24", "D) 26"], "answer": "C", "explanation": "The real rule is to multiply the previous term by 2 and then subtract 4, starting from the fourth term.", "topic": "Mixed Series (Alphanumeric)"}
# {"question": "In a family, Jonathan is the father-in-law of Johnny. Jon is the uncle of Johnny. Joan is the sister-in-law of Johnny's mother. Joni is the cousin of Johnny. If Johnny's mother has a brother, then that brother is the father of Joni. Joanne is the aunt of Johnny. If Jonathan has three children, then John is the brother of Johnny's mother. Johnny is the nephew of Jon. If Joni is married to the person who is the sibling of Johnny's aunt, then that person is the sister of Johnny's aunt. How is Joan related to Joni?", "choices": ["A) Aunt", "B) Mother", "C) Niece", "D) Brother"], "answer": "A", "explanation": "Jonathan is Johnny's father-in-law, making him Johnny's mother's husband. Joan is Johnny's mother's sister-in-law, thus she is Jonathan's sister. Joni is Johnny's cousin, so Joan is also Joni's aunt.", "topic": "Family tree logic"}
#
# ==================================================
#
#
# Time taken per batch generation: [67.4250876903534, 59.28304886817932, 63.8586688041687, 64.37191343307495]
# Tokens generated per batch: [1649, 1840, 2002, 2045]
# Total Time Taken: 254.939 seconds; Total Tokens: 7536; TGPS: 29.560 seconds
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Filtered 15
# Saved to outputs/questions.json!

# %% [markdown]
# #### Basic format-checks for questions from Q-agent
#
# Generated questions must follow the [format instructions](#format-overview). All questions generated from the Q-agent will be filtered and validated before being sent to the opponent's A-agent. We generate two version of questions, one is the raw, unfiltered one `questions.json` and the other is `filtered_questions.json` after passing through the below example filter. The full filtering and validation process is part of the judging system and is not demonstrated here.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("hf_models/huggingface/models--Qwen--Qwen3-4B/snapshots/1cfa9a7208912126459214e8b04321603b3df60c", padding_side='left')

def count_tokens_q(text: str) -> int:
    """Count the number of tokens using Qwen3-4B tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_questions(questions: List[str|Dict[str, str|Any]]) -> List[Dict[str, str|Any]]:
    def basic_checks(q2: Dict[str, str])->bool:
        # check required keys
        required_keys = ['topic', 'question', 'choices', 'answer']
        if all((key in q2) for key in required_keys):
            # check choices format
            checks = all(isinstance(choice, str) and len(choice) > 2 and choice[0].upper() in 'ABCD' for choice in q2['choices'])
            if isinstance(q2['choices'], list) and len(q2['choices']) == 4 and checks:
                # check answer format
                # Check token length
                check_len = sum(count_tokens_q(q2[k]) for k in ['question', 'answer'])
                check_len += sum(count_tokens_q(choice) for choice in q2['choices']) - 15
                if check_len < 130:
                    if check_len + count_tokens_q(q2.get('explanation', 'None')) <= 1024:
                        # Extra Checks: (PLUS checks) len(q2['answer']) == 1 and q2['answer'].upper() in 'ABCD':
                        if isinstance(q2['answer'], str):
                            return True
        return False
    correct_format_question = []
    for i, q in enumerate(questions):
        if isinstance(q, dict):
            if basic_checks(q):
                correct_format_question.append(q)
        elif isinstance(q, str):
            try:
                q1 = json.loads(q)
                if basic_checks(q1):
                    correct_format_question.append(q1)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {q}")
                continue
        else:
            continue
    if len(correct_format_question) >= 0.5 * len(questions):
        return correct_format_question
    return list()

# %%
with open("outputs/questions.json", "r") as f:
    questions = json.load(f)

filtered_questions = filter_questions(questions)

with open("outputs/filtered_questions.json", "w") as f:
    json.dump(filtered_questions, f, indent=4)

print(f"Number of questions: {len(questions)}")
print(f"Number of filtered questions: {len(filtered_questions)}")
# Out:
# Number of questions: 20
# Number of filtered questions: 18

# %% [markdown]
# ### A-agent
# <!-- 🤖  -->
# You will update the model in `answer_model.py`, which will be invoked by `answer_agent.py`. In the provided skeleton, we have again used the base Qwen3-4B model for A-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.

# %%
# Same instructions apply for the answer agent.
# For demo purpose, we have used the base Qwen3-4B model for A-agent. Participants are expected to improve upon this.
# !python -m agents.answer_agent \
    --input_file "outputs/filtered_questions.json" \
    --output_file "outputs/answers.json" \
    # --verbose
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100%|██████████████████| 8/8 [00:17<00:00,  2.18s/it]
# STEPS: 100%|███████████████████████████████████| 2/2 [00:20<00:00, 10.00s/batch]
# Saved answers to outputs/answers.json

# %% [markdown]
# #### Basic format-checks for answers from A-agent
# Generated answers must follow the [format instructions](#format-overview). The following filter is added into the `answer_agent.py`. Similar to before, two versions are saved, `answers.json` and `filtered_answers.json`. The latter is used for evaluation.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("hf_models/huggingface/models--Qwen--Qwen3-4B/snapshots/1cfa9a7208912126459214e8b04321603b3df60c", padding_side='left')

def count_tokens_a(text: str) -> int:
    """Count the number of tokens in the text using the agent's tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_answers(ans: List[str|Dict[str, str]]) -> List[Dict[str, str]]:
    r"""Filter answers to ensure they are in the correct format"""
    def basic_checks(a1: Dict[str, str])->bool:
        # check required keys
        required_keys = ['answer']
        if all((key in a1) and isinstance(a1[key], str) for key in required_keys):
            if len(a1['answer']) == 1 and (a1['answer'] not in 'ABCDabcd'):
                    return False
            check_len = count_tokens_a(a1['answer'])
            if check_len < 50:
                check_len += count_tokens_a(a1.get('reasoning', 'None'))
                if check_len < 512:
                    # check answer format - EXTRA checks
                    # if len(a1['answer']) == 1 and a1['answer'].upper() in 'ABCD':
                    return True
        return False

    filtered_answers = []
    for i, a in enumerate(ans):
        if isinstance(a, dict):
            if basic_checks(a):
                filtered_answers.append(a)
            else:
                filtered_answers.append(None)
        elif isinstance(a, str):
            # Basic checks: at least with correct JSON format
            try:
                a1 = json.loads(a)
                if basic_checks(a1):
                    filtered_answers.append(a1)
                else:
                    filtered_answers.append(None)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {a}")
                filtered_answers.append(None)
                continue
        else:
            # If the answer is neither a dict nor a str, skip it
            print(f"Skipping unsupported type at index {i}: {type(a)}")
            filtered_answers.append(None)
    return filtered_answers

# %%
with open("outputs/answers.json", "r") as f:
    answers = json.load(f)
filtered_answers = filter_answers(answers)


print(f"Number of answers: {len(answers)}")
print(f"Number of filtered answers: {len(filtered_answers)}")
# Out:
# Number of answers: 14
# Number of filtered answers: 14

# %% [markdown]
# ## Evaluation
# <!-- 🏅  -->

# %% [markdown]
# ### Scoring Criteria
#
# <!-- 📊  -->
#
# Scores are assigned based on: out of $N$ questions from Q-agent, how many an A-agent can answer and vice-versa. *No negative marking for wrong answers.*
#
# $$\text{A-agent Score} = \dfrac{\#\ \text{of questions correctly answered with expected format}}{N}\times 100$$
# $$\text{Q-agent Score} = \dfrac{\#\ \text{of questions incorrectly answered by A-agent}}{N}\times 100$$
#
#
# $N$ denotes the number of filtered / format-correct questions. **Teams whose Q-agent fails to generate at least $50\%$ of `num_questions` (where `num_questions` ranges from $2$ to $1000+$) of the questions correctly (as per [format-checking](#format-overview)) will be automatically disqualified.**<br>
#
# In case of **TIE**, closed benchmark questions will be used to evaluate the answer agents (A-agent) and rank the teams accordingly.

# %% [markdown]
# ### Scoring Example

# %%
# calculate scores...
N = len(filtered_questions)
assert N == len(filtered_answers), "Number of questions and answers must match."
num_correct_answers = 0

for q, a in zip(filtered_questions, filtered_answers):
    if a is not None:
        topic = q.get("topic", "Unknown")
        if q["answer"] == a["answer"]:
            num_correct_answers += 1
            # print(f"Correct | Topic: {topic}")
        else:
            print(f"Wrong   | Topic: {topic} | Expected: {q['answer']} | Got: {a['answer']}")

# Here the answer may be correct, but since q['answer'] is not an option letter is not there, we face problems
# Below shown is one way of simple string parsing
# num_correct_answers = len([1 for q,a in zip(filtered_questions, filtered_answers) if a is not None and q['answer'][0] == a['answer']])

a_score = num_correct_answers*100/(N+1e-9)
q_score = (N-num_correct_answers)*100/(N+1e-9)
# Announce the scores
print(f"Number of questions: {N}")
print(f"Number of correct answers: {num_correct_answers}")
print("Scores:")
print(f"Team B: A-agent score: {a_score:.2f}")
print(f"Team A: Q-agent score: {q_score:.2f}")
print(f"Innings 1 winner: {'Team A' if q_score > a_score else 'Team B' if q_score < a_score else 'Draw'}")
# Out:
# Wrong   | Topic: Mixed Series (Alphanumeric) | Expected: B | Got: C
# Wrong   | Topic: Seating Arrangements (Linear, Circular) | Expected: B | Got: C
# Wrong   | Topic: Mixed Series (Alphanumeric) | Expected: B | Got: C
# Wrong   | Topic: Syllogisms | Expected: D | Got: C
# Wrong   | Topic: Seating Arrangements (Linear, Circular) | Expected: B | Got: D
# Wrong   | Topic: Syllogisms | Expected: D | Got: C
# Wrong   | Topic: Seating Arrangements (Linear, Circular) | Expected: D | Got: B
# Wrong   | Topic: Syllogisms | Expected: D | Got: B
# Number of questions: 14
# Number of correct answers: 6
# Scores:
# Team B: A-agent score: 42.86
# Team A: Q-agent score: 57.14
# Innings 1 winner: Team A
